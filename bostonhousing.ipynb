# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahama1996/customer_review/blob/main/bostonhousing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-330e9a23-241d-4f6b-a62c-01e7d4c322ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-330e9a23-241d-4f6b-a62c-01e7d4c322ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
boston = pd.read_csv('train_boston.csv')
boston.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
boston.isna().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       333 non-null    int64
#  1   crim     333 non-null    float64
#  2   zn       333 non-null    float64
#  3   indus    333 non-null    float64
#  4   chas     333 non-null    int64
#  5   nox      333 non-null    float64
#  6   rm       333 non-null    float64
#  7   age      333 non-null    float64
#  8   dis      333 non-null    float64
#  9   rad      333 non-null    int64
#  10  tax      333 non-null    int64
#  11  ptratio  333 non-null    float64
#  12  black    333 non-null    float64
#  13  lstat    333 non-null    float64
#  14  medv     333 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 39.1 KB

# %%
boston.ID
# Out:
# 0        1
# 1        2
# 2        4
# 3        5
# 4        7
#       ...
# 328    500
# 329    502
# 330    503
# 331    504
# 332    506
# Name: ID, Length: 333, dtype: int64

# %%
boston.drop('ID', axis=1, inplace=True)

# %%
boston= boston.drop_duplicates(keep="first")
boston.shape
# Out:
# (333, 14)

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     3.360341   10.689189   11.293483    0.060060    0.557144    6.265619
# std      7.352272   22.674762    6.998123    0.237956    0.114955    0.703952
# min      0.006320    0.000000    0.740000    0.000000    0.385000    3.561000
# 25%      0.078960    0.000000    5.130000    0.000000    0.453000    5.884000
# 50%      0.261690    0.000000    9.900000    0.000000    0.538000    6.202000
# 75%      3.678220   12.500000   18.100000    0.000000    0.631000    6.595000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.725000
#
#               age         dis         rad         tax     ptratio       black  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean    68.226426    3.709934    9.633634  409.279279   18.448048  359.466096
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Exploratory Data Analysis

# %%
boston['indus'].plot(kind='hist', bins=20, title='indus')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.xlim(0,30)
# Out:
# (0.0, 30.0)

# %%
boston['zn'].plot(kind='hist', bins=20, title='zn')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
boston['crim'].plot(kind='hist', bins=20, title='crim')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.xlim(0,74)
# Out:
# (0.0, 74.0)

# %%
#correlation between variables
plt.figure(figsize=(20,6))
sns.heatmap(boston.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
sns.lineplot(x='zn', y='crim', data=boston)
# Out:
# <Axes: xlabel='zn', ylabel='crim'>

# %%
sns.lmplot(x='medv', y='lstat', data=boston)
sns.lmplot(x='medv', y='rm', data=boston)
sns.lmplot(x='medv', y='ptratio', data=boston)
sns.lmplot(x='medv', y='black', data=boston)

# %%
sns.catplot(data=boston, kind="swarm", x="rad", y="medv", col="chas")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 11.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 7.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import mean_absolute_percentage_error

# %%
#feature selection
features=['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad','ptratio', 'tax', 'lstat']
target=['medv']

# %%
X_train, X_test, y_train, y_test = train_test_split(boston[features], boston[target],
                                                    train_size=0.7, test_size=0.3, shuffle=False)

# %%
#data normalisation
from sklearn.preprocessing import MinMaxScaler
# fit scaler on training data
norm = MinMaxScaler().fit(X_train)

# transform training data
X_train_norm = norm.transform(X_train)

#transform testing data
X_test_norm = norm.transform(X_test)

# %%
#data standardisation
from sklearn.preprocessing import StandardScaler

# copy of datasets
X_train_stand = X_train.copy()
X_test_stand = X_test.copy()

# numerical features


# apply standardization on numerical features
for i in features:

    # fit on training data column
    scale = StandardScaler().fit(X_train_stand[[i]])


    # transform the training data column
    X_train_stand[i] = scale.transform(X_train_stand[[i]])

    # transform the testing data column
    X_test_stand[i] = scale.transform(X_test_stand[[i]])

# %%
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor()

# train the model
clf.fit(X_train_norm, y_train)

# predict on test data
predict = clf.predict(X_test_norm)
from sklearn.metrics import mean_squared_error, r2_score
#scatter plot of Actual vs predicted values
plt.scatter(y_test.medv, predict)
plt.ylabel('Predicted')
plt.xlabel('Actual')
print('RMSE: %.4f' % np.sqrt(mean_squared_error(y_test.medv, predict)))
print('r2 score: %.4f' % r2_score(y_test.medv, predict))
# Out:
# <ipython-input-24-3930c0428017>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_train_norm, y_train)
# RMSE: 7.1506
# r2 score: 0.2893

# %%
#distribution of the error values
plt.hist(y_test.medv-predict, bins=20)
# Out:
# (array([ 2.,  0.,  6., 11., 12., 20., 17., 15.,  9.,  3.,  0.,  1.,  0.,
#          0.,  1.,  0.,  0.,  0.,  0.,  3.]),
#  array([-15.059  , -12.82405, -10.5891 ,  -8.35415,  -6.1192 ,  -3.88425,
#          -1.6493 ,   0.58565,   2.8206 ,   5.05555,   7.2905 ,   9.52545,
#          11.7604 ,  13.99535,  16.2303 ,  18.46525,  20.7002 ,  22.93515,
#          25.1701 ,  27.40505,  29.64   ]),
#  <BarContainer object of 20 artists>)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
dtree = DecisionTreeRegressor(max_depth=8, min_samples_leaf=0.13, random_state=3)

dtree.fit(X_train_stand, y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=0.13, random_state=3)

# %%
DecisionTreeRegressor(criterion='mse')
# Out:
# DecisionTreeRegressor(criterion='mse')

# %%
predict2= dtree.predict(X_test_stand)

# %%
plt.scatter(y_test, predict2)
plt.ylabel('Predicted')
plt.xlabel('Actual')
print('RMSE: %.4f' % np.sqrt(mean_squared_error(y_test, predict2)))
print('r2 score: %.4f' % r2_score(y_test, predict2))
# Out:
# RMSE: 7.6379
# r2 score: 0.1892

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

quad = PolynomialFeatures (degree = 2)

x_quad = quad.fit_transform(X_train_norm)

plr = LinearRegression().fit(X_train_norm,y_train)

Y_train_pred = plr.predict(X_train_norm)
Y_test_pred = plr.predict(X_test_norm)

print(plr.score(X_test_norm,y_test))
# Out:
# -6.256321054157243

# %%
plt.scatter(y_test, Y_test_pred)
plt.ylabel('Predicted')
plt.xlabel('Actual')
print('RMSE: %.4f' % np.sqrt(mean_squared_error(y_test, Y_test_pred)))
print('r2 score: %.4f' % r2_score(y_test, Y_test_pred))
# Out:
# RMSE: 22.8491
# r2 score: -6.2563

# %%
plt.hist(y_test-Y_test_pred)
# Out:
# (array([ 1.,  0.,  0.,  3.,  1., 15., 37., 33.,  7.,  3.]),
#  array([-110.2748222 ,  -95.74728224,  -81.21974228,  -66.69220232,
#          -52.16466236,  -37.63712239,  -23.10958243,   -8.58204247,
#            5.94549749,   20.47303746,   35.00057742]),
#  <BarContainer object of 10 artists>)
